# %% [markdown]
# # Algo-trading: data preparation
#
#
# > Author: <b>Nicola Bini</b>
# >
# > Date:   <b>06/17/2021</b>
# >
# >
# > <b>Team 2:</b>
# > <i>
# > <br>Nicola Bini
# > <br>Felipe Domingues
# > <br>Tri Dung Dinh
# > <br>Manuel Echazarra
# > </i>
#
# # Summary
#
# This is a Keras LSTM model to predict whether or not the stock will close at higher price compared to the closing
# price of the previous day.
# Its predictions are then saved in a csv file as a signal for the bt library.

# %%
### Import libraries ###
from keras.models import Sequential       # Sequential model
from keras.layers import Dense            # Dense layer
from keras.layers import LSTM             # LSTM layer
from keras.layers import Dropout          # Dropout layer
#from tensorflow   import set_random_seed  # set random seed

import pandas            as pd
import numpy             as np
import matplotlib.pyplot as plt

# Set random seed for reproducible results
np.random.seed(42)

# %%
# Load data
data = pd.read_csv("./final_data.csv")
data = data.rename(columns = {"Unnamed: 0":"date"})
data = data.set_index("date")
data
# Out:
#              DNN       HGEN       ICLN        OCGN         VGT       VUZI  \
# date
# 2015-09-18  0.44  15.600000   9.390000  357.000000  102.790001   5.150000
# 2015-09-21  0.42  14.300000   9.410000  342.600006  103.639999   4.880000
# 2015-09-22  0.42  13.200000   9.200000  315.000000  102.019997   4.780000
# 2015-09-23  0.41  13.700000   9.060000  298.200012  101.180000   4.780000
# 2015-09-24  0.41  12.150000   9.020000  282.000000  101.080002   5.230000
# ...          ...        ...        ...         ...         ...        ...
# 2021-06-02  1.26  19.360001  22.500000    9.455000  372.720001  19.990000
# 2021-06-03  1.28  18.240000  22.090000    8.890000  368.730011  18.870001
# 2021-06-04  1.37  18.580000  22.299999    8.720000  375.700012  18.730000
# 2021-06-07  1.44  20.680000  22.420000   10.300000  376.220001  19.400000
# 2021-06-08  1.40  20.549999  22.510000   10.140000  376.880005  18.870001
#
#                    XLV         ^NBI  price%_DNN  price%_HGEN  ...   sma_XLV  \
# date                                                          ...
# 2015-09-18   70.910004  3732.669922    0.000000    -0.031056  ...  1.014546
# 2015-09-21   69.970001  3568.250000   -0.045455    -0.083333  ...  1.013110
# 2015-09-22   69.540001  3508.300049    0.000000    -0.076923  ...  1.011404
# 2015-09-23   69.470001  3488.520020   -0.023810     0.037879  ...  1.009513
# 2015-09-24   68.760002  3418.729980    0.000000    -0.113139  ...  1.007465
# ...                ...          ...         ...          ...  ...       ...
# 2021-06-02  121.330002  4749.950195   -0.045455     0.039184  ...  1.067943
# 2021-06-03  121.699997  4744.620117    0.015873    -0.057851  ...  1.068541
# 2021-06-04  122.089996  4803.450195    0.070313     0.018640  ...  1.069211
# 2021-06-07  122.529999  4977.330078    0.051095     0.113025  ...  1.069835
# 2021-06-08  122.150002  4972.700195   -0.027778    -0.006286  ...  1.070011
#
#             sma_^NBI  profit_DNN  profit_HGEN  profit_ICLN  profit_OCGN  \
# date
# 2015-09-18  1.053607         1.0          1.0          0.0          1.0
# 2015-09-21  1.051290         0.0          1.0          1.0          1.0
# 2015-09-22  1.048319         1.0          0.0          1.0          1.0
# 2015-09-23  1.044806         0.0          1.0          1.0          1.0
# 2015-09-24  1.040933         1.0          1.0          0.0          0.0
# ...              ...         ...          ...          ...          ...
# 2021-06-02  1.019637         0.0          1.0          1.0          1.0
# 2021-06-03  1.019038         0.0          0.0          0.0          1.0
# 2021-06-04  1.019199         0.0          0.0          0.0          0.0
# 2021-06-07  1.019640         1.0          1.0          0.0          1.0
# 2021-06-08  1.019998         1.0          0.0          0.0          1.0
#
#             profit_VGT  profit_VUZI  profit_XLV  profit_^NBI
# date
# 2015-09-18         0.0          1.0         1.0          1.0
# 2015-09-21         1.0          1.0         1.0          1.0
# 2015-09-22         1.0          0.0         1.0          1.0
# 2015-09-23         1.0          0.0         1.0          1.0
# 2015-09-24         1.0          1.0         1.0          1.0
# ...                ...          ...         ...          ...
# 2021-06-02         1.0          1.0         0.0          1.0
# 2021-06-03         0.0          1.0         0.0          0.0
# 2021-06-04         0.0          0.0         0.0          0.0
# 2021-06-07         0.0          1.0         1.0          1.0
# 2021-06-08         0.0          0.0         0.0          0.0
#
# [1440 rows x 40 columns]

# %%
# DNN and ICLN Energy
# OCGN and ^NBI Biotechonlogy
# HGEN and XLV Healthcare
# VUGI and VGT Vision 

ticket     = 'HGEN'
index_fund = 'XLV'

lookback = 15 # Days
split_date = '2018-06-01' # Data goes from '2015-09-18' to '2021-06-08'

drop_columns = ["profit_" + index_fund,ticket,index_fund]
for col in data.columns:
    #print(col)
     if ticket not in col and index_fund not in col:
            drop_columns.append(col)

        
df_data = data.drop(drop_columns, axis=1)

df_train = df_data[df_data.index < split_date]
df_test  = df_data[df_data.index > split_date]

train_date = df_train.reset_index()
train_date = train_date['date']
train_date
test_date = df_test.reset_index()
test_date = test_date['date']
test_date
# Out:
# 0      2018-06-04
# 1      2018-06-05
# 2      2018-06-06
# 3      2018-06-07
# 4      2018-06-08
#           ...
# 754    2021-06-02
# 755    2021-06-03
# 756    2021-06-04
# 757    2021-06-07
# 758    2021-06-08
# Name: date, Length: 759, dtype: object

# %%
drop_columns
# Out:
# ['profit_XLV',
#  'HGEN',
#  'XLV',
#  'DNN',
#  'ICLN',
#  'OCGN',
#  'VGT',
#  'VUZI',
#  '^NBI',
#  'price%_DNN',
#  'price%_ICLN',
#  'price%_OCGN',
#  'price%_VGT',
#  'price%_VUZI',
#  'price%_^NBI',
#  'RSI_DNN',
#  'RSI_ICLN',
#  'RSI_OCGN',
#  'RSI_VGT',
#  'RSI_VUZI',
#  'RSI_^NBI',
#  'sma_DNN',
#  'sma_ICLN',
#  'sma_OCGN',
#  'sma_VGT',
#  'sma_VUZI',
#  'sma_^NBI',
#  'profit_DNN',
#  'profit_ICLN',
#  'profit_OCGN',
#  'profit_VGT',
#  'profit_VUZI',
#  'profit_^NBI']

# %%
x_train = df_train.drop(["profit_" + ticket], axis=1)
y_train = df_train['profit_' + ticket]

x_test = df_test.drop(["profit_" + ticket], axis=1)
y_test = df_test['profit_' + ticket]

# %%
def create_dataset_with_lookback(data, lookback):
    
    data = np.array(data)
    
    data_w_timesteps = np.zeros((data.shape[0]-lookback, lookback, data.shape[1]), dtype=np.float)
    #print("data_w_timesteps shape: ", data_w_timesteps.shape)
    
    for i in range(data_w_timesteps.shape[0]):
        for i2 in range(10):
            data_w_timesteps[i][i2] = data[i + i2]
    
    return data_w_timesteps
    
# Data with time steps
x_train_tm = create_dataset_with_lookback(x_train, lookback)
x_test_tm = create_dataset_with_lookback(x_test, lookback)

# %%
train_date = train_date.tail(y_train.shape[0]-lookback-1)
test_date  = test_date.tail(y_test.shape[0]-lookback)

x_train    = x_train[1:]
y_train_tm = y_train.tail(y_train.shape[0]-lookback-1)
y_test_tm  = y_test.tail(y_test.shape[0]-lookback)

x_train_tm = create_dataset_with_lookback(x_train, lookback)
x_test_tm = create_dataset_with_lookback(x_test, lookback)

# %%
print("x_train shape: ", x_train_tm.shape)
print("y_train shape: ", y_train_tm.shape)
print("x_test shape: ",  x_test_tm.shape)
print("y_test shape: ",  y_test_tm.shape)
train_date.shape
# Out:
# x_train shape:  (664, 15, 6)
# y_train shape:  (664,)
# x_test shape:  (744, 15, 6)
# y_test shape:  (744,)
# (664,)

# %%
y_train_tm.value_counts()
# Out:
# 0.0    352
# 1.0    312
# Name: profit_HGEN, dtype: int64

# %%
### LSTM model ###

model = Sequential()

model.add(LSTM(units = 250, return_sequences = True, input_shape=(lookback, x_train_tm.shape[2])))
#model.add(Dropout(0.2))

model.add(LSTM(units = 250, return_sequences = True))
#model.add(Dropout(0.2))

model.add(LSTM(units = 250, return_sequences = True))
#model.add(Dropout(0.2))

model.add(Dense(units = 50))
#model.add(Dropout(0.2))

model.add(Dense(units = 1, activation='sigmoid'))

model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics=['accuracy'])

#model.build()
history = model.fit(x_train_tm, 
                    y_train_tm,
                    epochs           = 100, 
                    batch_size       = 16,
                    shuffle          = True,
                    validation_split = 0.2,
                    verbose          = 1)
# Out:
# Epoch 1/100
# 34/34 [==============================] - 7s 66ms/step - loss: 0.7118 - accuracy: 0.4904 - val_loss: 0.6909 - val_accuracy: 0.5830
# Epoch 2/100
# 34/34 [==============================] - 1s 43ms/step - loss: 0.6932 - accuracy: 0.5062 - val_loss: 0.6789 - val_accuracy: 0.6015
# Epoch 3/100
# 34/34 [==============================] - 1s 42ms/step - loss: 0.6941 - accuracy: 0.5154 - val_loss: 0.6898 - val_accuracy: 0.5815
# Epoch 4/100
# 34/34 [==============================] - 1s 40ms/step - loss: 0.6920 - accuracy: 0.5311 - val_loss: 0.6946 - val_accuracy: 0.4571
# Epoch 5/100
# 34/34 [==============================] - 2s 50ms/step - loss: 0.6929 - accuracy: 0.5189 - val_loss: 0.6957 - val_accuracy: 0.4566
# Epoch 6/100
# 34/34 [==============================] - 2s 51ms/step - loss: 0.6923 - accuracy: 0.5067 - val_loss: 0.7128 - val_accuracy: 0.4110
# Epoch 7/100
# 34/34 [==============================] - 2s 68ms/step - loss: 0.6919 - accuracy: 0.5313 - val_loss: 0.7038 - val_accuracy: 0.4256
# Epoch 8/100
# 34/34 [==============================] - 3s 83ms/step - loss: 0.6981 - accuracy: 0.5065 - val_loss: 0.6906 - val_accuracy: 0.5945
# Epoch 9/100
# 34/34 [==============================] - 3s 89ms/step - loss: 0.6939 - accuracy: 0.4991 - val_loss: 0.6963 - val_accuracy: 0.4301
# Epoch 10/100
# 34/34 [==============================] - 4s 120ms/step - loss: 0.6916 - accuracy: 0.5213 - val_loss: 0.6944 - val_accuracy: 0.4602
# Epoch 11/100
# 34/34 [==============================] - 5s 145ms/step - loss: 0.6941 - accuracy: 0.5086 - val_loss: 0.6956 - val_accuracy: 0.4401
# Epoch 12/100
# 34/34 [==============================] - 5s 149ms/step - loss: 0.6911 - accuracy: 0.5302 - val_loss: 0.6846 - val_accuracy: 0.6015
# Epoch 13/100
# 34/34 [==============================] - 4s 123ms/step - loss: 0.6923 - accuracy: 0.5215 - val_loss: 0.6917 - val_accuracy: 0.4832
# Epoch 14/100
# 34/34 [==============================] - 3s 100ms/step - loss: 0.6909 - accuracy: 0.5348 - val_loss: 0.6887 - val_accuracy: 0.5218
# Epoch 15/100
# 34/34 [==============================] - 2s 71ms/step - loss: 0.6908 - accuracy: 0.5048 - val_loss: 0.6994 - val_accuracy: 0.4366
# Epoch 16/100
# 34/34 [==============================] - 2s 70ms/step - loss: 0.6910 - accuracy: 0.5422 - val_loss: 0.6911 - val_accuracy: 0.4692
# Epoch 17/100
# 34/34 [==============================] - 2s 70ms/step - loss: 0.6918 - accuracy: 0.5258 - val_loss: 0.6893 - val_accuracy: 0.4947
# Epoch 18/100
# 34/34 [==============================] - 2s 73ms/step - loss: 0.6935 - accuracy: 0.5110 - val_loss: 0.7032 - val_accuracy: 0.4010
# Epoch 19/100
# 34/34 [==============================] - 2s 59ms/step - loss: 0.6904 - accuracy: 0.5340 - val_loss: 0.6921 - val_accuracy: 0.4546
# Epoch 20/100
# 34/34 [==============================] - 2s 72ms/step - loss: 0.6906 - accuracy: 0.5235 - val_loss: 0.6931 - val_accuracy: 0.4491
# Epoch 21/100
# 34/34 [==============================] - 2s 67ms/step - loss: 0.6945 - accuracy: 0.5077 - val_loss: 0.6943 - val_accuracy: 0.4481
# Epoch 22/100
# 34/34 [==============================] - 2s 70ms/step - loss: 0.6933 - accuracy: 0.5360 - val_loss: 0.6875 - val_accuracy: 0.6015
# Epoch 23/100
# 34/34 [==============================] - 3s 80ms/step - loss: 0.6908 - accuracy: 0.5272 - val_loss: 0.6979 - val_accuracy: 0.4331
# Epoch 24/100
# 34/34 [==============================] - 2s 63ms/step - loss: 0.6901 - accuracy: 0.5499 - val_loss: 0.6888 - val_accuracy: 0.5208
# Epoch 25/100
# 34/34 [==============================] - 2s 62ms/step - loss: 0.6896 - accuracy: 0.5433 - val_loss: 0.6958 - val_accuracy: 0.4501
# Epoch 26/100
# 34/34 [==============================] - 2s 72ms/step - loss: 0.6909 - accuracy: 0.5189 - val_loss: 0.6913 - val_accuracy: 0.5043
# Epoch 27/100
# 34/34 [==============================] - 3s 84ms/step - loss: 0.6956 - accuracy: 0.4944 - val_loss: 0.6886 - val_accuracy: 0.6015
# Epoch 28/100
# 34/34 [==============================] - 3s 90ms/step - loss: 0.6932 - accuracy: 0.5134 - val_loss: 0.6933 - val_accuracy: 0.4887
# Epoch 29/100
# 34/34 [==============================] - 3s 97ms/step - loss: 0.6931 - accuracy: 0.4879 - val_loss: 0.6978 - val_accuracy: 0.4135
# Epoch 30/100
# 34/34 [==============================] - 3s 94ms/step - loss: 0.6891 - accuracy: 0.5102 - val_loss: 0.6861 - val_accuracy: 0.5253
# Epoch 31/100
# 34/34 [==============================] - 3s 95ms/step - loss: 0.6958 - accuracy: 0.5109 - val_loss: 0.6923 - val_accuracy: 0.5383
# Epoch 32/100
# 34/34 [==============================] - 3s 89ms/step - loss: 0.6900 - accuracy: 0.5332 - val_loss: 0.6973 - val_accuracy: 0.4607
# Epoch 33/100
# 34/34 [==============================] - 3s 78ms/step - loss: 0.6928 - accuracy: 0.5306 - val_loss: 0.6901 - val_accuracy: 0.5348
# Epoch 34/100
# 34/34 [==============================] - 3s 76ms/step - loss: 0.6899 - accuracy: 0.5269 - val_loss: 0.6955 - val_accuracy: 0.4341
# Epoch 35/100
# 34/34 [==============================] - 2s 73ms/step - loss: 0.6915 - accuracy: 0.5284 - val_loss: 0.6948 - val_accuracy: 0.4386
# Epoch 36/100
# 34/34 [==============================] - 3s 87ms/step - loss: 0.6894 - accuracy: 0.5291 - val_loss: 0.6903 - val_accuracy: 0.5158
# Epoch 37/100
# 34/34 [==============================] - 3s 77ms/step - loss: 0.6913 - accuracy: 0.5131 - val_loss: 0.6995 - val_accuracy: 0.3990
# Epoch 38/100
# 34/34 [==============================] - 3s 82ms/step - loss: 0.6902 - accuracy: 0.5271 - val_loss: 0.6869 - val_accuracy: 0.5599
# Epoch 39/100
# 34/34 [==============================] - 3s 85ms/step - loss: 0.6917 - accuracy: 0.5129 - val_loss: 0.6898 - val_accuracy: 0.5133
# Epoch 40/100
# 34/34 [==============================] - 3s 94ms/step - loss: 0.6904 - accuracy: 0.5376 - val_loss: 0.6898 - val_accuracy: 0.5063
# Epoch 41/100
# 34/34 [==============================] - 3s 74ms/step - loss: 0.6903 - accuracy: 0.5198 - val_loss: 0.6914 - val_accuracy: 0.4612
# Epoch 42/100
# 34/34 [==============================] - 3s 79ms/step - loss: 0.6901 - accuracy: 0.5419 - val_loss: 0.7004 - val_accuracy: 0.4055
# Epoch 43/100
# 34/34 [==============================] - 3s 81ms/step - loss: 0.6902 - accuracy: 0.5375 - val_loss: 0.6970 - val_accuracy: 0.4190
# Epoch 44/100
# 34/34 [==============================] - 3s 86ms/step - loss: 0.6895 - accuracy: 0.5347 - val_loss: 0.6926 - val_accuracy: 0.4596
# Epoch 45/100
# 34/34 [==============================] - 4s 106ms/step - loss: 0.6884 - accuracy: 0.5371 - val_loss: 0.6909 - val_accuracy: 0.5068
# Epoch 46/100
# 34/34 [==============================] - 5s 133ms/step - loss: 0.6895 - accuracy: 0.5535 - val_loss: 0.6836 - val_accuracy: 0.5529
# Epoch 47/100
# 34/34 [==============================] - 5s 148ms/step - loss: 0.6971 - accuracy: 0.5205 - val_loss: 0.6889 - val_accuracy: 0.5574
# Epoch 48/100
# 34/34 [==============================] - 5s 134ms/step - loss: 0.6928 - accuracy: 0.5193 - val_loss: 0.6926 - val_accuracy: 0.5018
# Epoch 49/100
# 34/34 [==============================] - 4s 129ms/step - loss: 0.6918 - accuracy: 0.5230 - val_loss: 0.6911 - val_accuracy: 0.5464
# Epoch 50/100
# 34/34 [==============================] - 5s 138ms/step - loss: 0.6902 - accuracy: 0.5490 - val_loss: 0.6933 - val_accuracy: 0.4586
# Epoch 51/100
# 34/34 [==============================] - 3s 99ms/step - loss: 0.6902 - accuracy: 0.5363 - val_loss: 0.7048 - val_accuracy: 0.4306
# Epoch 52/100
# 34/34 [==============================] - 3s 92ms/step - loss: 0.6900 - accuracy: 0.5048 - val_loss: 0.6929 - val_accuracy: 0.4832
# Epoch 53/100
# 34/34 [==============================] - 3s 98ms/step - loss: 0.6914 - accuracy: 0.5335 - val_loss: 0.6899 - val_accuracy: 0.5118
# Epoch 54/100
# 34/34 [==============================] - 3s 88ms/step - loss: 0.6912 - accuracy: 0.4988 - val_loss: 0.6893 - val_accuracy: 0.5494
# Epoch 55/100
# 34/34 [==============================] - 3s 96ms/step - loss: 0.6884 - accuracy: 0.5259 - val_loss: 0.6966 - val_accuracy: 0.4566
# Epoch 56/100
# 34/34 [==============================] - 4s 112ms/step - loss: 0.6910 - accuracy: 0.5112 - val_loss: 0.6994 - val_accuracy: 0.3985
# Epoch 57/100
# 34/34 [==============================] - 4s 117ms/step - loss: 0.6896 - accuracy: 0.5116 - val_loss: 0.6897 - val_accuracy: 0.4882
# Epoch 58/100
# 34/34 [==============================] - 5s 141ms/step - loss: 0.6867 - accuracy: 0.5420 - val_loss: 0.7055 - val_accuracy: 0.4336
# Epoch 59/100
# 34/34 [==============================] - 4s 119ms/step - loss: 0.6871 - accuracy: 0.5453 - val_loss: 0.6923 - val_accuracy: 0.4446
# Epoch 60/100
# 34/34 [==============================] - 4s 123ms/step - loss: 0.6951 - accuracy: 0.5024 - val_loss: 0.7073 - val_accuracy: 0.4030
# Epoch 61/100
# 34/34 [==============================] - 4s 119ms/step - loss: 0.6937 - accuracy: 0.5087 - val_loss: 0.6954 - val_accuracy: 0.5263
# Epoch 62/100
# 34/34 [==============================] - 4s 126ms/step - loss: 0.6885 - accuracy: 0.5227 - val_loss: 0.7170 - val_accuracy: 0.4802
# Epoch 63/100
# 34/34 [==============================] - 3s 102ms/step - loss: 0.6887 - accuracy: 0.5382 - val_loss: 0.6975 - val_accuracy: 0.4301
# Epoch 64/100
# 34/34 [==============================] - 3s 101ms/step - loss: 0.6884 - accuracy: 0.5468 - val_loss: 0.6864 - val_accuracy: 0.5454
# Epoch 65/100
# 34/34 [==============================] - 3s 89ms/step - loss: 0.6974 - accuracy: 0.5163 - val_loss: 0.6965 - val_accuracy: 0.5018
# Epoch 66/100
# 34/34 [==============================] - 3s 84ms/step - loss: 0.6910 - accuracy: 0.5166 - val_loss: 0.6941 - val_accuracy: 0.4421
# Epoch 67/100
# 34/34 [==============================] - 3s 92ms/step - loss: 0.6892 - accuracy: 0.5345 - val_loss: 0.6927 - val_accuracy: 0.4812
# Epoch 68/100
# 34/34 [==============================] - 3s 77ms/step - loss: 0.6869 - accuracy: 0.5416 - val_loss: 0.7059 - val_accuracy: 0.4802
# Epoch 69/100
# 34/34 [==============================] - 3s 80ms/step - loss: 0.6883 - accuracy: 0.5230 - val_loss: 0.6870 - val_accuracy: 0.5439
# Epoch 70/100
# 34/34 [==============================] - 3s 77ms/step - loss: 0.6875 - accuracy: 0.5309 - val_loss: 0.7041 - val_accuracy: 0.4391
# Epoch 71/100
# 34/34 [==============================] - 3s 78ms/step - loss: 0.6878 - accuracy: 0.5382 - val_loss: 0.6988 - val_accuracy: 0.5118
# Epoch 72/100
# 34/34 [==============================] - 3s 77ms/step - loss: 0.6866 - accuracy: 0.5495 - val_loss: 0.6916 - val_accuracy: 0.4767
# Epoch 73/100
# 34/34 [==============================] - 3s 81ms/step - loss: 0.6844 - accuracy: 0.5574 - val_loss: 0.7019 - val_accuracy: 0.5439
# Epoch 74/100
# 34/34 [==============================] - 3s 74ms/step - loss: 0.6864 - accuracy: 0.5421 - val_loss: 0.6947 - val_accuracy: 0.4536
# Epoch 75/100
# 34/34 [==============================] - 3s 83ms/step - loss: 0.6827 - accuracy: 0.5567 - val_loss: 0.6862 - val_accuracy: 0.5579
# Epoch 76/100
# 34/34 [==============================] - 3s 86ms/step - loss: 0.6875 - accuracy: 0.5433 - val_loss: 0.7121 - val_accuracy: 0.4531
# Epoch 77/100
# 34/34 [==============================] - 3s 89ms/step - loss: 0.6847 - accuracy: 0.5564 - val_loss: 0.6913 - val_accuracy: 0.5033
# Epoch 78/100
# 34/34 [==============================] - 3s 85ms/step - loss: 0.6846 - accuracy: 0.5323 - val_loss: 0.7122 - val_accuracy: 0.4877
# Epoch 79/100
# 34/34 [==============================] - 3s 92ms/step - loss: 0.6865 - accuracy: 0.5675 - val_loss: 0.6903 - val_accuracy: 0.4877
# Epoch 80/100
# 34/34 [==============================] - 3s 94ms/step - loss: 0.6875 - accuracy: 0.5543 - val_loss: 0.6868 - val_accuracy: 0.5398
# Epoch 81/100
# 34/34 [==============================] - 3s 92ms/step - loss: 0.6829 - accuracy: 0.5579 - val_loss: 0.7429 - val_accuracy: 0.4386
# Epoch 82/100
# 34/34 [==============================] - 3s 98ms/step - loss: 0.6885 - accuracy: 0.5567 - val_loss: 0.6841 - val_accuracy: 0.5609
# Epoch 83/100
# 34/34 [==============================] - 4s 109ms/step - loss: 0.6828 - accuracy: 0.5608 - val_loss: 0.7074 - val_accuracy: 0.4842
# Epoch 84/100
# 34/34 [==============================] - 3s 100ms/step - loss: 0.6833 - accuracy: 0.5539 - val_loss: 0.7177 - val_accuracy: 0.4596
# Epoch 85/100
# 34/34 [==============================] - 4s 106ms/step - loss: 0.6832 - accuracy: 0.5599 - val_loss: 0.7083 - val_accuracy: 0.4857
# Epoch 86/100
# 34/34 [==============================] - 4s 113ms/step - loss: 0.6809 - accuracy: 0.5591 - val_loss: 0.7272 - val_accuracy: 0.4702
# Epoch 87/100
# 34/34 [==============================] - 3s 100ms/step - loss: 0.6837 - accuracy: 0.5538 - val_loss: 0.6860 - val_accuracy: 0.5348
# Epoch 88/100
# 34/34 [==============================] - 4s 111ms/step - loss: 0.6833 - accuracy: 0.5559 - val_loss: 0.7020 - val_accuracy: 0.4622
# Epoch 89/100
# 34/34 [==============================] - 3s 96ms/step - loss: 0.6829 - accuracy: 0.5667 - val_loss: 0.7342 - val_accuracy: 0.4456
# Epoch 90/100
# 34/34 [==============================] - 3s 89ms/step - loss: 0.6843 - accuracy: 0.5616 - val_loss: 0.6902 - val_accuracy: 0.4992
# Epoch 91/100
# 34/34 [==============================] - 3s 83ms/step - loss: 0.6822 - accuracy: 0.5602 - val_loss: 0.7451 - val_accuracy: 0.4692
# Epoch 92/100
# 34/34 [==============================] - 3s 94ms/step - loss: 0.6829 - accuracy: 0.5617 - val_loss: 0.6904 - val_accuracy: 0.5108
# Epoch 93/100
# 34/34 [==============================] - 3s 92ms/step - loss: 0.6784 - accuracy: 0.5681 - val_loss: 0.7054 - val_accuracy: 0.5298
# Epoch 94/100
# 34/34 [==============================] - 3s 97ms/step - loss: 0.6928 - accuracy: 0.5291 - val_loss: 0.6934 - val_accuracy: 0.4466
# Epoch 95/100
# 34/34 [==============================] - 3s 84ms/step - loss: 0.6843 - accuracy: 0.5417 - val_loss: 0.7071 - val_accuracy: 0.4361
# Epoch 96/100
# 34/34 [==============================] - 3s 88ms/step - loss: 0.6829 - accuracy: 0.5544 - val_loss: 0.7361 - val_accuracy: 0.4446
# Epoch 97/100
# 34/34 [==============================] - 3s 100ms/step - loss: 0.6829 - accuracy: 0.5653 - val_loss: 0.6910 - val_accuracy: 0.4887
# Epoch 98/100
# 34/34 [==============================] - 4s 130ms/step - loss: 0.6818 - accuracy: 0.5685 - val_loss: 0.6955 - val_accuracy: 0.5023
# Epoch 99/100
# 34/34 [==============================] - 4s 125ms/step - loss: 0.6793 - accuracy: 0.5642 - val_loss: 0.6888 - val_accuracy: 0.5143
# Epoch 100/100
# 34/34 [==============================] - 4s 112ms/step - loss: 0.6774 - accuracy: 0.5670 - val_loss: 0.6978 - val_accuracy: 0.5068

# %%
print(history.history.keys())

plt.plot(history.history['loss'], label="loss")
plt.plot(history.history['accuracy'], label="accuracy")
plt.plot(history.history['val_loss'], label="val_loss")
plt.plot(history.history['val_accuracy'],label="val_accuracy")
plt.legend()
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
### Save train ###

y_train_preds_intervals = model.predict_classes(x_train_tm)
y_train_preds           = []
for pred_interval in y_train_preds_intervals:
    p0 = 0
    p1 = 0
    for pred in pred_interval:
        if pred == 0:
            p0 = p0 + 1
        elif pred == 1:
            p1 = p1 + 1
        else:
            print("Error!!")
            break
    if p1 >= p0:
        y_train_preds.append(1)
    else:
        y_train_preds.append(0)

train_preds = pd.DataFrame({ticket : y_train_preds}, index = train_date)
print(train_preds.value_counts())
train_preds.to_csv("train_signal_" + ticket + ".csv", index=True)


### Save test ### 

y_test_preds_intervals = model.predict_classes(x_test_tm)
y_test_preds           = []
for pred_interval in y_test_preds_intervals:
    p0 = 0
    p1 = 0
    for pred in pred_interval:
        if pred == 0:
            p0 = p0 + 1
        elif pred == 1:
            p1 = p1 + 1
        else:
            print("Error!!")
            break
    if p1 >= p0:
        y_test_preds.append(1)
    else:
        y_test_preds.append(0)

test_preds = pd.DataFrame({ticket : y_test_preds}, index = test_date)
print(test_preds.value_counts())
test_preds.to_csv("test_signal_" + ticket + ".csv", index=True)
# Out:
# /Users/nicolabini/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:455: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# HGEN
# 1       355
# 0       309
# dtype: int64
# HGEN
# 1       489
# 0       255
# dtype: int64
