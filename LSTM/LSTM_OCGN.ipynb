# %% [markdown]
# # Algo-trading: data preparation
#
#
# > Author: <b>Nicola Bini</b>
# >
# > Date:   <b>06/17/2021</b>
# >
# >
# > <b>Team 2:</b>
# > <i>
# > <br>Nicola Bini
# > <br>Felipe Domingues
# > <br>Tri Dung Dinh
# > <br>Manuel Echazarra
# > </i>
#
# # Summary
#
# This is a Keras LSTM model to predict whether or not the stock will close at higher price compared to the closing
# price of the previous day.
# Its predictions are then saved in a .csv file as a signal for the bt library.

# %%
### Import libraries ###
from keras.models import Sequential       # Sequential model
from keras.layers import Dense            # Dense layer
from keras.layers import LSTM             # LSTM layer
from keras.layers import Dropout          # Dropout layer
import keras
from keras.utils.vis_utils import plot_model
#from tensorflow   import set_random_seed  # set random seed

import pandas            as pd
import numpy             as np
import matplotlib.pyplot as plt

# Set random seed for reproducible results
np.random.seed(42)

# %%
# Load data
data = pd.read_csv("./final_data.csv")
data = data.rename(columns = {"Unnamed: 0":"date"})
data = data.set_index("date")
data
# Out:
#              DNN       HGEN       ICLN        OCGN         VGT       VUZI  \
# date
# 2015-09-18  0.44  15.600000   9.390000  357.000000  102.790001   5.150000
# 2015-09-21  0.42  14.300000   9.410000  342.600006  103.639999   4.880000
# 2015-09-22  0.42  13.200000   9.200000  315.000000  102.019997   4.780000
# 2015-09-23  0.41  13.700000   9.060000  298.200012  101.180000   4.780000
# 2015-09-24  0.41  12.150000   9.020000  282.000000  101.080002   5.230000
# ...          ...        ...        ...         ...         ...        ...
# 2021-06-02  1.26  19.360001  22.500000    9.455000  372.720001  19.990000
# 2021-06-03  1.28  18.240000  22.090000    8.890000  368.730011  18.870001
# 2021-06-04  1.37  18.580000  22.299999    8.720000  375.700012  18.730000
# 2021-06-07  1.44  20.680000  22.420000   10.300000  376.220001  19.400000
# 2021-06-08  1.40  20.549999  22.510000   10.140000  376.880005  18.870001
#
#                    XLV         ^NBI  price%_DNN  price%_HGEN  ...   sma_XLV  \
# date                                                          ...
# 2015-09-18   70.910004  3732.669922    0.000000    -0.031056  ...  1.014546
# 2015-09-21   69.970001  3568.250000   -0.045455    -0.083333  ...  1.013110
# 2015-09-22   69.540001  3508.300049    0.000000    -0.076923  ...  1.011404
# 2015-09-23   69.470001  3488.520020   -0.023810     0.037879  ...  1.009513
# 2015-09-24   68.760002  3418.729980    0.000000    -0.113139  ...  1.007465
# ...                ...          ...         ...          ...  ...       ...
# 2021-06-02  121.330002  4749.950195   -0.045455     0.039184  ...  1.067943
# 2021-06-03  121.699997  4744.620117    0.015873    -0.057851  ...  1.068541
# 2021-06-04  122.089996  4803.450195    0.070313     0.018640  ...  1.069211
# 2021-06-07  122.529999  4977.330078    0.051095     0.113025  ...  1.069835
# 2021-06-08  122.150002  4972.700195   -0.027778    -0.006286  ...  1.070011
#
#             sma_^NBI  profit_DNN  profit_HGEN  profit_ICLN  profit_OCGN  \
# date
# 2015-09-18  1.053607         1.0          1.0          0.0          1.0
# 2015-09-21  1.051290         0.0          1.0          1.0          1.0
# 2015-09-22  1.048319         1.0          0.0          1.0          1.0
# 2015-09-23  1.044806         0.0          1.0          1.0          1.0
# 2015-09-24  1.040933         1.0          1.0          0.0          0.0
# ...              ...         ...          ...          ...          ...
# 2021-06-02  1.019637         0.0          1.0          1.0          1.0
# 2021-06-03  1.019038         0.0          0.0          0.0          1.0
# 2021-06-04  1.019199         0.0          0.0          0.0          0.0
# 2021-06-07  1.019640         1.0          1.0          0.0          1.0
# 2021-06-08  1.019998         1.0          0.0          0.0          1.0
#
#             profit_VGT  profit_VUZI  profit_XLV  profit_^NBI
# date
# 2015-09-18         0.0          1.0         1.0          1.0
# 2015-09-21         1.0          1.0         1.0          1.0
# 2015-09-22         1.0          0.0         1.0          1.0
# 2015-09-23         1.0          0.0         1.0          1.0
# 2015-09-24         1.0          1.0         1.0          1.0
# ...                ...          ...         ...          ...
# 2021-06-02         1.0          1.0         0.0          1.0
# 2021-06-03         0.0          1.0         0.0          0.0
# 2021-06-04         0.0          0.0         0.0          0.0
# 2021-06-07         0.0          1.0         1.0          1.0
# 2021-06-08         0.0          0.0         0.0          0.0
#
# [1440 rows x 40 columns]

# %%
# DNN and ICLN Energy
# OCGN and ^NBI Biotechonlogy
# HGEN and XLV Healthcare
# VUGI and VGT Vision 


ticket     = 'OCGN'
index_fund = '^NBI'

lookback = 15 # Days
split_date = '2018-06-01' # Data goes from '2015-09-18' to '2021-06-08'

drop_columns = ["profit_" + index_fund,ticket,index_fund]
for col in data.columns:
    #print(col)
     if ticket not in col and index_fund not in col:
            drop_columns.append(col)

        
df_data = data.drop(drop_columns, axis=1)

df_train = df_data[df_data.index < split_date]
df_test  = df_data[df_data.index > split_date]

train_date = df_train.reset_index()
train_date = train_date['date']
train_date
test_date = df_test.reset_index()
test_date = test_date['date']
test_date
# Out:
# 0      2018-06-04
# 1      2018-06-05
# 2      2018-06-06
# 3      2018-06-07
# 4      2018-06-08
#           ...
# 754    2021-06-02
# 755    2021-06-03
# 756    2021-06-04
# 757    2021-06-07
# 758    2021-06-08
# Name: date, Length: 759, dtype: object

# %%
drop_columns
# Out:
# ['profit_^NBI',
#  'OCGN',
#  '^NBI',
#  'DNN',
#  'HGEN',
#  'ICLN',
#  'VGT',
#  'VUZI',
#  'XLV',
#  'price%_DNN',
#  'price%_HGEN',
#  'price%_ICLN',
#  'price%_VGT',
#  'price%_VUZI',
#  'price%_XLV',
#  'RSI_DNN',
#  'RSI_HGEN',
#  'RSI_ICLN',
#  'RSI_VGT',
#  'RSI_VUZI',
#  'RSI_XLV',
#  'sma_DNN',
#  'sma_HGEN',
#  'sma_ICLN',
#  'sma_VGT',
#  'sma_VUZI',
#  'sma_XLV',
#  'profit_DNN',
#  'profit_HGEN',
#  'profit_ICLN',
#  'profit_VGT',
#  'profit_VUZI',
#  'profit_XLV']

# %%
x_train = df_train.drop(["profit_" + ticket], axis=1)
y_train = df_train['profit_' + ticket]

x_test = df_test.drop(["profit_" + ticket], axis=1)
y_test = df_test['profit_' + ticket]

# %%
def create_dataset_with_lookback(data, lookback):
    
    data = np.array(data)
    
    data_w_timesteps = np.zeros((data.shape[0]-lookback, lookback, data.shape[1]), dtype=np.float)
    #print("data_w_timesteps shape: ", data_w_timesteps.shape)
    
    for i in range(data_w_timesteps.shape[0]):
        for i2 in range(10):
            data_w_timesteps[i][i2] = data[i + i2]
    
    return data_w_timesteps
    
# Data with time steps
x_train_tm = create_dataset_with_lookback(x_train, lookback)
x_test_tm = create_dataset_with_lookback(x_test, lookback)

# %%
train_date = train_date.tail(y_train.shape[0]-lookback-1)
test_date  = test_date.tail(y_test.shape[0]-lookback)

x_train    = x_train[1:]
y_train_tm = y_train.tail(y_train.shape[0]-lookback-1)
y_test_tm  = y_test.tail(y_test.shape[0]-lookback)

x_train_tm = create_dataset_with_lookback(x_train, lookback)
x_test_tm = create_dataset_with_lookback(x_test, lookback)

# %%
print("x_train shape: ", x_train_tm.shape)
print("y_train shape: ", y_train_tm.shape)
print("x_test shape: ",  x_test_tm.shape)
print("y_test shape: ",  y_test_tm.shape)
# Out:
# x_train shape:  (664, 15, 6)
# y_train shape:  (664,)
# x_test shape:  (744, 15, 6)
# y_test shape:  (744,)

# %%
y_train_tm.value_counts()
# Out:
# 0.0    337
# 1.0    327
# Name: profit_OCGN, dtype: int64

# %%
### LSTM model ###

model = Sequential()

model.add(LSTM(units = 250, return_sequences = True, input_shape=(lookback, x_train_tm.shape[2])))
model.add(Dropout(0.2))

model.add(LSTM(units = 250, return_sequences = True))
model.add(Dropout(0.2))

model.add(Dense(units = 50))
model.add(Dropout(0.2))

model.add(Dense(units = 1, activation='sigmoid'))
optimizer = keras.optimizers.Adam(learning_rate=0.05)
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics=['accuracy'])

#model.build()
history = model.fit(x_train_tm, 
                    y_train_tm,
                    epochs           = 100, 
                    batch_size       = 16,
                    shuffle          = True,
                    validation_split = 0.2,
                    verbose          = 1)
# Out:
# Epoch 1/100
# 42/42 [==============================] - 4s 22ms/step - loss: 0.7162 - accuracy: 0.4863
# Epoch 2/100
# 42/42 [==============================] - 1s 23ms/step - loss: 0.6975 - accuracy: 0.5078 0s - loss: 0.6955 - accu
# Epoch 3/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.7007 - accuracy: 0.5149
# Epoch 4/100
# 42/42 [==============================] - 1s 23ms/step - loss: 0.7005 - accuracy: 0.4905
# Epoch 5/100
# 42/42 [==============================] - 1s 20ms/step - loss: 0.6954 - accuracy: 0.4959
# Epoch 6/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6957 - accuracy: 0.5188
# Epoch 7/100
# 42/42 [==============================] - 1s 22ms/step - loss: 0.6955 - accuracy: 0.5066
# Epoch 8/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6933 - accuracy: 0.5097
# Epoch 9/100
# 42/42 [==============================] - 1s 22ms/step - loss: 0.6945 - accuracy: 0.4958
# Epoch 10/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6945 - accuracy: 0.5046
# Epoch 11/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6940 - accuracy: 0.5014
# Epoch 12/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6935 - accuracy: 0.5102
# Epoch 13/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6942 - accuracy: 0.4950
# Epoch 14/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6936 - accuracy: 0.5110 0s - loss: 0.6932 - accuracy: 0.51
# Epoch 15/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6944 - accuracy: 0.5041
# Epoch 16/100
# 42/42 [==============================] - 1s 22ms/step - loss: 0.6940 - accuracy: 0.5083
# Epoch 17/100
# 42/42 [==============================] - 1s 22ms/step - loss: 0.6937 - accuracy: 0.4932
# Epoch 18/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6937 - accuracy: 0.5135
# Epoch 19/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6940 - accuracy: 0.5085
# Epoch 20/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6941 - accuracy: 0.4987
# Epoch 21/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6938 - accuracy: 0.4920
# Epoch 22/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6933 - accuracy: 0.5079
# Epoch 23/100
# 42/42 [==============================] - 1s 22ms/step - loss: 0.6934 - accuracy: 0.5091
# Epoch 24/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6934 - accuracy: 0.5015
# Epoch 25/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6939 - accuracy: 0.5004
# Epoch 26/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6934 - accuracy: 0.5122
# Epoch 27/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6933 - accuracy: 0.5114
# Epoch 28/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6933 - accuracy: 0.4905
# Epoch 29/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6936 - accuracy: 0.5111
# Epoch 30/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6930 - accuracy: 0.5031
# Epoch 31/100
# 42/42 [==============================] - 1s 22ms/step - loss: 0.6928 - accuracy: 0.5132
# Epoch 32/100
# 42/42 [==============================] - 1s 23ms/step - loss: 0.6930 - accuracy: 0.5084
# Epoch 33/100
# 42/42 [==============================] - 1s 26ms/step - loss: 0.6940 - accuracy: 0.5114
# Epoch 34/100
# 42/42 [==============================] - 1s 23ms/step - loss: 0.6940 - accuracy: 0.4760
# Epoch 35/100
# 42/42 [==============================] - 1s 22ms/step - loss: 0.6932 - accuracy: 0.5217
# Epoch 36/100
# 42/42 [==============================] - 1s 22ms/step - loss: 0.6932 - accuracy: 0.5124
# Epoch 37/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6932 - accuracy: 0.5094
# Epoch 38/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6936 - accuracy: 0.5093
# Epoch 39/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6926 - accuracy: 0.5180
# Epoch 40/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6937 - accuracy: 0.5101
# Epoch 41/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6926 - accuracy: 0.5155
# Epoch 42/100
# 42/42 [==============================] - 1s 22ms/step - loss: 0.6942 - accuracy: 0.4938
# Epoch 43/100
# 42/42 [==============================] - 1s 22ms/step - loss: 0.6926 - accuracy: 0.5126
# Epoch 44/100
# 42/42 [==============================] - 1s 22ms/step - loss: 0.6924 - accuracy: 0.5184
# Epoch 45/100
# 42/42 [==============================] - 1s 22ms/step - loss: 0.6932 - accuracy: 0.5136
# Epoch 46/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6915 - accuracy: 0.5166
# Epoch 47/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6931 - accuracy: 0.4970
# Epoch 48/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6928 - accuracy: 0.5130
# Epoch 49/100
# 42/42 [==============================] - 1s 22ms/step - loss: 0.6925 - accuracy: 0.5174
# Epoch 50/100
# 42/42 [==============================] - 1s 22ms/step - loss: 0.6927 - accuracy: 0.5128
# Epoch 51/100
# 42/42 [==============================] - 1s 22ms/step - loss: 0.6929 - accuracy: 0.5168
# Epoch 52/100
# 42/42 [==============================] - 1s 22ms/step - loss: 0.6927 - accuracy: 0.5131
# Epoch 53/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6922 - accuracy: 0.5232
# Epoch 54/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6929 - accuracy: 0.5112
# Epoch 55/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6926 - accuracy: 0.5118
# Epoch 56/100
# 42/42 [==============================] - 1s 22ms/step - loss: 0.6925 - accuracy: 0.5103
# Epoch 57/100
# 42/42 [==============================] - 1s 22ms/step - loss: 0.6923 - accuracy: 0.5180
# Epoch 58/100
# 42/42 [==============================] - 1s 22ms/step - loss: 0.6924 - accuracy: 0.5141
# Epoch 59/100
# 42/42 [==============================] - 1s 22ms/step - loss: 0.6935 - accuracy: 0.5151
# Epoch 60/100
# 42/42 [==============================] - 1s 22ms/step - loss: 0.6937 - accuracy: 0.4993
# Epoch 61/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6932 - accuracy: 0.5062
# Epoch 62/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6930 - accuracy: 0.5128
# Epoch 63/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6937 - accuracy: 0.5121
# Epoch 64/100
# 42/42 [==============================] - 1s 22ms/step - loss: 0.6932 - accuracy: 0.5085
# Epoch 65/100
# 42/42 [==============================] - 1s 22ms/step - loss: 0.6929 - accuracy: 0.5082
# Epoch 66/100
# 42/42 [==============================] - 1s 22ms/step - loss: 0.6934 - accuracy: 0.5142
# Epoch 67/100
# 42/42 [==============================] - 1s 22ms/step - loss: 0.6932 - accuracy: 0.5079
# Epoch 68/100
# 42/42 [==============================] - 1s 22ms/step - loss: 0.6925 - accuracy: 0.5200
# Epoch 69/100
# 42/42 [==============================] - 1s 22ms/step - loss: 0.6928 - accuracy: 0.5115
# Epoch 70/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6931 - accuracy: 0.5174
# Epoch 71/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6917 - accuracy: 0.5250
# Epoch 72/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6940 - accuracy: 0.5136
# Epoch 73/100
# 42/42 [==============================] - 1s 22ms/step - loss: 0.6928 - accuracy: 0.5107
# Epoch 74/100
# 42/42 [==============================] - 1s 22ms/step - loss: 0.6928 - accuracy: 0.5164
# Epoch 75/100
# 42/42 [==============================] - 1s 22ms/step - loss: 0.6925 - accuracy: 0.5202
# Epoch 76/100
# 42/42 [==============================] - 1s 22ms/step - loss: 0.6920 - accuracy: 0.5231
# Epoch 77/100
# 42/42 [==============================] - 1s 22ms/step - loss: 0.6927 - accuracy: 0.5012
# Epoch 78/100
# 42/42 [==============================] - 1s 22ms/step - loss: 0.6915 - accuracy: 0.5257
# Epoch 79/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6938 - accuracy: 0.5156
# Epoch 80/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6922 - accuracy: 0.5202
# Epoch 81/100
# 42/42 [==============================] - 1s 23ms/step - loss: 0.6926 - accuracy: 0.5082
# Epoch 82/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6928 - accuracy: 0.5114
# Epoch 83/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6920 - accuracy: 0.5208
# Epoch 84/100
# 42/42 [==============================] - 1s 22ms/step - loss: 0.6923 - accuracy: 0.5209
# Epoch 85/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6910 - accuracy: 0.5246
# Epoch 86/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6919 - accuracy: 0.5191
# Epoch 87/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6918 - accuracy: 0.5265
# Epoch 88/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6926 - accuracy: 0.5234
# Epoch 89/100
# 42/42 [==============================] - 1s 22ms/step - loss: 0.6917 - accuracy: 0.5216
# Epoch 90/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6919 - accuracy: 0.5280
# Epoch 91/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6907 - accuracy: 0.5272
# Epoch 92/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6915 - accuracy: 0.5219
# Epoch 93/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.6920 - accuracy: 0.5266
# Epoch 94/100
# 42/42 [==============================] - 1s 22ms/step - loss: 0.6921 - accuracy: 0.5188
# Epoch 95/100
# 42/42 [==============================] - 1s 22ms/step - loss: 0.6912 - accuracy: 0.5218
# Epoch 96/100
# 42/42 [==============================] - 1s 21ms/step - loss: 0.7001 - accuracy: 0.5302
# Epoch 97/100
# 42/42 [==============================] - 1s 22ms/step - loss: 0.6919 - accuracy: 0.5246
# Epoch 98/100
# 42/42 [==============================] - 1s 22ms/step - loss: 0.6934 - accuracy: 0.5237
# Epoch 99/100
# 42/42 [==============================] - 1s 22ms/step - loss: 0.6935 - accuracy: 0.5089
# Epoch 100/100
# 42/42 [==============================] - 1s 22ms/step - loss: 0.6931 - accuracy: 0.5075

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 15, 250)           257000
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 15, 250)           0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 15, 250)           501000
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 15, 250)           0
# _________________________________________________________________
# dense_2 (Dense)              (None, 15, 50)            12550
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 15, 50)            0
# _________________________________________________________________
# dense_3 (Dense)              (None, 15, 1)             51
# =================================================================
# Total params: 770,601
# Trainable params: 770,601
# Non-trainable params: 0
# _________________________________________________________________

# %%
#0.4578
print(history.history.keys())

plt.plot(history.history['loss'], label="loss")
plt.plot(history.history['accuracy'], label="accuracy")
#plt.plot(history.history['val_loss'], label="val_loss")
#plt.plot(history.history['val_accuracy'],label="val_accuracy")
plt.legend()
plt.show()

# %%
### Save train ###

y_train_preds_intervals = model.predict_classes(x_train_tm)
y_train_preds           = []
for pred_interval in y_train_preds_intervals:
    p0 = 0
    p1 = 0
    for pred in pred_interval:
        if pred == 0:
            p0 = p0 + 1
        elif pred == 1:
            p1 = p1 + 1
        else:
            print("Error!!")
            break
    if p1 >= p0:
        y_train_preds.append(1)
    else:
        y_train_preds.append(0)

train_preds = pd.DataFrame({ticket : y_train_preds}, index = train_date)
print(train_preds.value_counts())
train_preds.to_csv("train_signal_" + ticket + ".csv", index=True)


### Save test ### 

y_test_preds_intervals = model.predict_classes(x_test_tm)
y_test_preds           = []
for pred_interval in y_test_preds_intervals:
    p0 = 0
    p1 = 0
    for pred in pred_interval:
        if pred == 0:
            p0 = p0 + 1
        elif pred == 1:
            p1 = p1 + 1
        else:
            print("Error!!")
            break
    if p1 >= p0:
        y_test_preds.append(1)
    else:
        y_test_preds.append(0)

test_preds = pd.DataFrame({ticket : y_test_preds}, index = test_date)
print(test_preds.value_counts())
test_preds.to_csv("test_signal_" + ticket + ".csv", index=True)
